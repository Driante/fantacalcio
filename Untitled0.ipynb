# %% [markdown]
# <a href="https://colab.research.google.com/github/Driante/fantacalcio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd 
import numpy as np
import io
drive.mount('/content/drive')
fname = "Calendario_Campionato---A-buon-rendere.xlsx"
dir_andre= 'Doc/Fantacalcio/Fanta_Analysis/'
df = pd.read_excel('/content/drive/My Drive/'+dir_andre+fname)

# %%
df = df.drop(['Unnamed: 5'], axis=1)
df = df.dropna()
df[:10]
# Out:
#    Calendario Campionato - A buon rendere  ...  Unnamed: 10
# 3                              Gargantua   ...          3-3
# 4                              asdMalerba  ...          5-3
# 5                       Civediamoamaggio   ...          4-6
# 6                           Barriera-team  ...          2-1
# 8                              asdMalerba  ...            -
# 9                       Civediamoamaggio   ...            -
# 10                          Barriera-team  ...            -
# 11                               Paris FC  ...            -
# 13                             asdMalerba  ...            -
# 14                      Civediamoamaggio   ...            -
#
# [10 rows x 10 columns]
