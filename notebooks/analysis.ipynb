# %% [markdown]
# <a href="https://colab.research.google.com/github/Driante/fantacalcio/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import io, os

# %%
calendarFile = 'Calendario_Campionato---A-buon-rendere.xlsx'
rootPath = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
pathToCalendar = os.path.join(rootPath,'data',calendarFile)

# %%
#la mia idea futura è rpendere direttamente il calendario dal sito, ma non so come farlo. Ora come ora bisogna scaricarselo a mano dal sito
#https://leghe.fantacalcio.it/legafantaboys/calendario e caricarlo
#eseguendo questa cella 
#from google.colab import files
#uploaded = files.upload()
#Altrimenti se si è scaricato la cartella da github
df2 = pd.read_excel(pathToCalendar)

# %%
#Itera su tutte le colonne e vedi dove ci sono le parole "Giornata lega". La mia idea è di costruire prima
#un data frame 
for col in df2:
    print(col)
    s = df2[col].astype(str).str.contains('Giornata lega')
    s.fillna(False,inplace=True)
    Rows = np.where(s)[0]
    for row in Rows:
# Out:
# Calendario Campionato - A buon rendere
# [ 2  7 12 17 22 27 32 37 42 47 52 57 62 67 72 77 82 87]
# Unnamed: 1
# []
# Unnamed: 2
# []
# Unnamed: 3
# []
# Unnamed: 4
# []
# Unnamed: 5
# []
# Unnamed: 6
# [ 2  7 12 17 22 27 32 37 42 47 52 57 62 67 72 77 82]
# Unnamed: 7
# []
# Unnamed: 8
# []
# Unnamed: 9
# []
# Unnamed: 10
# []

# %%
df2['Unnamed: 1'][2]
# Out:
# nan

# %%
a = np.nan

# %%
fname = 'dataset.xlsx'
df = pd.read_excel(fname)
df = df.dropna() #drop the null values
df.goal = df.goal.astype(int) #convert data.goal in int (da float che era)
df.head()

# %%
df2
# Out:
#         Calendario Campionato - A buon rendere  Unnamed: 1  \
# 0   https://leghe.fantacalcio.it/legafantaboys         NaN
# 1                                          NaN         NaN
# 2                             1ª Giornata lega         NaN
# 3                                   Gargantua         64.0
# 4                                   asdMalerba        74.0
# 5                            Civediamoamaggio         70.5
# 6                                Barriera-team        70.0
# 7                             3ª Giornata lega         NaN
# 8                                   asdMalerba         0.0
# 9                            Civediamoamaggio          0.0
# 10                               Barriera-team         0.0
# 11                                    Paris FC         0.0
# 12                            5ª Giornata lega         NaN
# 13                                  asdMalerba         0.0
# 14                           Civediamoamaggio          0.0
# 15                        Atletico Manontroppo         0.0
# 16                                    Paris FC         0.0
# 17                            7ª Giornata lega         NaN
# 18                                  asdMalerba         0.0
# 19                        Atletico Manontroppo         0.0
# 20                                    Paris FC         0.0
# 21                                CACCOLA F.C.         0.0
# 22                            9ª Giornata lega         NaN
# 23                               Barriera-team         0.0
# 24                           Civediamoamaggio          0.0
# 25                                  asdMalerba         0.0
# 26                                  Gargantua          0.0
# 27                           11ª Giornata lega         NaN
# 28                           Civediamoamaggio          0.0
# 29                                  asdMalerba         0.0
# ..                                         ...         ...
# 62                           25ª Giornata lega         NaN
# 63                           Civediamoamaggio          0.0
# 64                                  asdMalerba         0.0
# 65                                    Paris FC         0.0
# 66                               Barriera-team         0.0
# 67                           27ª Giornata lega         NaN
# 68                                    Paris FC         0.0
# 69                        Atletico Manontroppo         0.0
# 70                                CACCOLA F.C.         0.0
# 71                                  asdMalerba         0.0
# 72                           29ª Giornata lega         NaN
# 73                                  Gargantua          0.0
# 74                                  asdMalerba         0.0
# 75                           Civediamoamaggio          0.0
# 76                               Barriera-team         0.0
# 77                           31ª Giornata lega         NaN
# 78                                  asdMalerba         0.0
# 79                           Civediamoamaggio          0.0
# 80                               Barriera-team         0.0
# 81                                    Paris FC         0.0
# 82                           33ª Giornata lega         NaN
# 83                                  asdMalerba         0.0
# 84                           Civediamoamaggio          0.0
# 85                        Atletico Manontroppo         0.0
# 86                                    Paris FC         0.0
# 87                           35ª Giornata lega         NaN
# 88                                  asdMalerba         0.0
# 89                        Atletico Manontroppo         0.0
# 90                                    Paris FC         0.0
# 91                                CACCOLA F.C.         0.0
#
#               Unnamed: 2            Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0                    NaN                   NaN        NaN         NaN
# 1                    NaN                   NaN        NaN         NaN
# 2    4ª Giornata serie a                   NaN        NaN         NaN
# 3                     83      Capitan Martella        0-5         NaN
# 4                     79          CACCOLA F.C.        3-4         NaN
# 5                   70.5              Paris FC        2-2         NaN
# 6                   83.5  Atletico Manontroppo        2-5         NaN
# 7    6ª Giornata serie a                   NaN        NaN         NaN
# 8                      0  Atletico Manontroppo          -         NaN
# 9                      0      Capitan Martella          -         NaN
# 10                     0            Gargantua           -         NaN
# 11                     0          CACCOLA F.C.          -         NaN
# 12   8ª Giornata serie a                   NaN        NaN         NaN
# 13                     0            Gargantua           -         NaN
# 14                     0         Barriera-team          -         NaN
# 15                     0          CACCOLA F.C.          -         NaN
# 16                     0      Capitan Martella          -         NaN
# 17  10ª Giornata serie a                   NaN        NaN         NaN
# 18                     0     Civediamoamaggio           -         NaN
# 19                     0            Gargantua           -         NaN
# 20                     0         Barriera-team          -         NaN
# 21                     0      Capitan Martella          -         NaN
# 22  12ª Giornata serie a                   NaN        NaN         NaN
# 23                     0      Capitan Martella          -         NaN
# 24                     0  Atletico Manontroppo          -         NaN
# 25                     0              Paris FC          -         NaN
# 26                     0          CACCOLA F.C.          -         NaN
# 27  14ª Giornata serie a                   NaN        NaN         NaN
# 28                     0            Gargantua           -         NaN
# 29                     0      Capitan Martella          -         NaN
# ..                   ...                   ...        ...         ...
# 62  28ª Giornata serie a                   NaN        NaN         NaN
# 63                     0            Gargantua           -         NaN
# 64                     0      Capitan Martella          -         NaN
# 65                     0  Atletico Manontroppo          -         NaN
# 66                     0          CACCOLA F.C.          -         NaN
# 67  30ª Giornata serie a                   NaN        NaN         NaN
# 68                     0            Gargantua           -         NaN
# 69                     0      Capitan Martella          -         NaN
# 70                     0     Civediamoamaggio           -         NaN
# 71                     0         Barriera-team          -         NaN
# 72  32ª Giornata serie a                   NaN        NaN         NaN
# 73                     0      Capitan Martella          -         NaN
# 74                     0          CACCOLA F.C.          -         NaN
# 75                     0              Paris FC          -         NaN
# 76                     0  Atletico Manontroppo          -         NaN
# 77  34ª Giornata serie a                   NaN        NaN         NaN
# 78                     0  Atletico Manontroppo          -         NaN
# 79                     0      Capitan Martella          -         NaN
# 80                     0            Gargantua           -         NaN
# 81                     0          CACCOLA F.C.          -         NaN
# 82  36ª Giornata serie a                   NaN        NaN         NaN
# 83                     0            Gargantua           -         NaN
# 84                     0         Barriera-team          -         NaN
# 85                     0          CACCOLA F.C.          -         NaN
# 86                     0      Capitan Martella          -         NaN
# 87  38ª Giornata serie a                   NaN        NaN         NaN
# 88                     0     Civediamoamaggio           -         NaN
# 89                     0            Gargantua           -         NaN
# 90                     0         Barriera-team          -         NaN
# 91                     0      Capitan Martella          -         NaN
#
#               Unnamed: 6  Unnamed: 7            Unnamed: 8  \
# 0                    NaN         NaN                   NaN
# 1                    NaN         NaN                   NaN
# 2       2ª Giornata lega         NaN   5ª Giornata serie a
# 3       Capitan Martella        74.5                    75
# 4   Atletico Manontroppo        82.5                  75.5
# 5               Paris FC        78.5                    86
# 6           CACCOLA F.C.        72.0                  66.5
# 7       4ª Giornata lega         NaN   7ª Giornata serie a
# 8             Gargantua          0.0                     0
# 9       Capitan Martella         0.0                     0
# 10  Atletico Manontroppo         0.0                     0
# 11          CACCOLA F.C.         0.0                     0
# 12      6ª Giornata lega         NaN   9ª Giornata serie a
# 13            Gargantua          0.0                     0
# 14      Capitan Martella         0.0                     0
# 15     Civediamoamaggio          0.0                     0
# 16         Barriera-team         0.0                     0
# 17      8ª Giornata lega         NaN  11ª Giornata serie a
# 18      Capitan Martella         0.0                     0
# 19          CACCOLA F.C.         0.0                     0
# 20              Paris FC         0.0                     0
# 21  Atletico Manontroppo         0.0                     0
# 22     10ª Giornata lega         NaN  13ª Giornata serie a
# 23  Atletico Manontroppo         0.0                     0
# 24      Capitan Martella         0.0                     0
# 25            Gargantua          0.0                     0
# 26          CACCOLA F.C.         0.0                     0
# 27     12ª Giornata lega         NaN  15ª Giornata serie a
# 28            Gargantua          0.0                     0
# 29         Barriera-team         0.0                     0
# ..                   ...         ...                   ...
# 62     26ª Giornata lega         NaN  29ª Giornata serie a
# 63            Gargantua          0.0                     0
# 64         Barriera-team         0.0                     0
# 65          CACCOLA F.C.         0.0                     0
# 66      Capitan Martella         0.0                     0
# 67     28ª Giornata lega         NaN  31ª Giornata serie a
# 68     Civediamoamaggio          0.0                     0
# 69            Gargantua          0.0                     0
# 70         Barriera-team         0.0                     0
# 71      Capitan Martella         0.0                     0
# 72     30ª Giornata lega         NaN  33ª Giornata serie a
# 73      Capitan Martella         0.0                     0
# 74  Atletico Manontroppo         0.0                     0
# 75              Paris FC         0.0                     0
# 76          CACCOLA F.C.         0.0                     0
# 77     32ª Giornata lega         NaN  35ª Giornata serie a
# 78            Gargantua          0.0                     0
# 79      Capitan Martella         0.0                     0
# 80  Atletico Manontroppo         0.0                     0
# 81          CACCOLA F.C.         0.0                     0
# 82     34ª Giornata lega         NaN  37ª Giornata serie a
# 83            Gargantua          0.0                     0
# 84      Capitan Martella         0.0                     0
# 85     Civediamoamaggio          0.0                     0
# 86         Barriera-team         0.0                     0
# 87                   NaN         NaN                   NaN
# 88                   NaN         NaN                   NaN
# 89                   NaN         NaN                   NaN
# 90                   NaN         NaN                   NaN
# 91                   NaN         NaN                   NaN
#
#               Unnamed: 9 Unnamed: 10
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN         NaN
# 3          Barriera-team         3-3
# 4      Civediamoamaggio          5-3
# 5             asdMalerba         4-6
# 6             Gargantua          2-1
# 7                    NaN         NaN
# 8      Civediamoamaggio            -
# 9             asdMalerba           -
# 10              Paris FC           -
# 11         Barriera-team           -
# 12                   NaN         NaN
# 13              Paris FC           -
# 14  Atletico Manontroppo           -
# 15          CACCOLA F.C.           -
# 16            asdMalerba           -
# 17                   NaN         NaN
# 18            Gargantua            -
# 19            asdMalerba           -
# 20     Civediamoamaggio            -
# 21         Barriera-team           -
# 22                   NaN         NaN
# 23            asdMalerba           -
# 24     Civediamoamaggio            -
# 25         Barriera-team           -
# 26              Paris FC           -
# 27                   NaN         NaN
# 28            asdMalerba           -
# 29     Civediamoamaggio            -
# ..                   ...         ...
# 62                   NaN         NaN
# 63            asdMalerba           -
# 64     Civediamoamaggio            -
# 65  Atletico Manontroppo           -
# 66              Paris FC           -
# 67                   NaN         NaN
# 68            asdMalerba           -
# 69  Atletico Manontroppo           -
# 70              Paris FC           -
# 71          CACCOLA F.C.           -
# 72                   NaN         NaN
# 73         Barriera-team           -
# 74     Civediamoamaggio            -
# 75            asdMalerba           -
# 76            Gargantua            -
# 77                   NaN         NaN
# 78     Civediamoamaggio            -
# 79            asdMalerba           -
# 80              Paris FC           -
# 81         Barriera-team           -
# 82                   NaN         NaN
# 83              Paris FC           -
# 84  Atletico Manontroppo           -
# 85          CACCOLA F.C.           -
# 86            asdMalerba           -
# 87                   NaN         NaN
# 88                   NaN         NaN
# 89                   NaN         NaN
# 90                   NaN         NaN
# 91                   NaN         NaN
#
# [92 rows x 11 columns]

# %%
data = df.copy() #creo una copia 
data.drop(columns=['fantapunti', 'subiti'], inplace=True) #drop unuseful variables
data = data.pivot(index='squadra', columns='giornata', values='goal') #reshape the dataset

# %%
lenght, width = data.shape #larghezza del dataset
#rinominare le colonne 
nomi_colonne = []
for i in range(1,width+1):
    nomi_colonne.append('goal'+ str(i))
data.columns = nomi_colonne
data.sort_values(["squadra"], inplace=True) #per semplicità voglio ordinare le squadre in ordine alfabetico
data

# %% [markdown]
# ## Analisi vera e propria

# %%
#ora che ho il dataset pronto, posso passare all'analisi
from itertools import permutations, product #permutations non serve ad un cazzo
from matplotlib import pyplot as plt #matplotlib
# %matplotlib inline
import seaborn as sns #seaborn
plt.rcParams['figure.figsize'] = 15,5 #grandezza grafico

# %%
lista_confronti=[]
for i in data.columns: #per ogni colonna (ogni giornata)...
    i = list(product(data[i], data[i])) #... paragonami ogni numero, quindi 64 (8*8) coppie per ogni giornata
    lista_confronti.append(i)

# %%
giornate = len(lista_confronti) #quante partite abbiamo giorcato
matrici88_giornate = [] #matrici 8*8
for i in range(giornate): #cioè per ogni giornata
    for elementi in lista_confronti[i]: 
        elementi = elementi[0] - elementi[1] #goal fatto - subito, cioè le coppie che ho generato in lista_confronti (sopra)
        if elementi > 0: #vittoria
            elementi = 3
        elif elementi < 0: #sconfitta
            elementi = 0
        else:  #pareggio
            elementi = 1
        matrici88_giornate.append(elementi)
matrici88_giornate = np.array(matrici88_giornate).reshape((giornate, 8, 8)) 
#organizza la lista che hai appena creato nel seguente modo:
    #ci sono tante matrici 8*8 quante sono le giornate
matrici88_giornate #ogni matrice è una giornata
#(sulle righe di ogni matrice abbiamo la performance degli otto giocatori)

# %%
#creo questa matrice per togliere il punto che ad ogni giornata veniva precendentemente assegnato di default 
    #(questo accadeva perché tutti giocavano contro se stessi)
validation_matrix = np.ones([giornate,8,8])
d3, row, col = validation_matrix.shape
for k in range(d3):
    for i in range(row):
        for j in range(col):
            if i == j: 
                validation_matrix[k,i,j] = 0

matrici88_giornate = matrici88_giornate * validation_matrix

# %% [markdown]
# ## I punti in ogni giornata

# %%
#non ricordo come funziona la np.sum, con axis=2, funziona solo per 3D array, era nella lezione03_03 del corso LinkedIn
punti_giornata = matrici88_giornate.sum(axis=2)  
punti_giornata #ora ogni riga rappresenta una giornata, ogni colonna un giocatore, ma a me serve la trasposta

# %%
punti_giornata = punti_giornata.T #ora ogni matrice rappresenta la performance di ogni giocatore nelle giornate
punti_giornata = pd.DataFrame(punti_giornata) 
punti_giornata.set_index(data.index, inplace=True)
punti_giornata.columns = data.columns

# %%
#setto i nomi delle variabili, ora sono uguali ai nomi delle variabili del dataset originale
punti_giornata.columns = data.columns #ma voglio cambiare la parola 'goal' che non va bene
nuovi_nomi = []
for elementi in punti_giornata.columns:
    elementi = elementi.replace('goal','punti') #sostituisci la parola 'goal' con la parola 'punti'
    nuovi_nomi.append(elementi)
punti_giornata.columns = nuovi_nomi
punti_giornata = punti_giornata.astype(int) #trasformiamo i valori del dataframe in int
punti_giornata

# %% [markdown]
# ## Heatmap

# %%
plt.rcParams['figure.figsize'] = 15,7
sns.heatmap(punti_giornata.T, cmap="PiYG", xticklabels=punti_giornata.index, yticklabels=False); 
#at the bottom trovi le ultime giornate, in alto le prime

# %% [markdown]
# ## Classifica Finale

# %%
#non sono sicuro che devo necessariamente trasformare il dataframe in np.matrix/array per poter sommare orizzontalmente
    #(axis=0 somma verticale)
classifica_finale = np.asmatrix(punti_giornata).sum(axis=1)

# %%
data['classifica_finale'] = classifica_finale #aggiungo la classifica finale al dataset 
data.sort_values(["classifica_finale"], ascending=False, inplace=True) #ordinare dal più alto al più basso
classifica_finale = data['classifica_finale'] #per tenere solo la classifica (creo un altro dataset)
classifica_finale

# %%
(classifica_finale/7).round(1)

# %% [markdown]
# ## Barchart

# %%
import warnings
warnings.filterwarnings('ignore')

sns.set(style="whitegrid")
sns.barplot(x=data.index, y=data.classifica_finale);
